# %% [markdown]
# This assignment will give you practice with regular expressions (and other Python skills) by processing data on cumulative case counts and deaths in every county/parish in the US for covid-19. These data are compiled and updated regulary by the NY Times, and made available on GitHub: https://github.com/nytimes/covid-19-data. I downloaded the data on March 30th and have included that file (covidData_3.30.20.txt) in this week's repository.
#
# Each cell in this Jupyter notebook includes a comment that indicates what I want you to accomplish with Python code. To submit your assignment, please create your own folder (with your name) inside the assignments folder for this week. In this folder, please put the completed notebook and the new files you created. Please submit these via a pull request to the class GitHub page, as with previous weeks.
#
# If you have *any questions at all*, please let me know. I will be available for office hours via Zoom at our regularly scheduled class times. I'll also respond to all emails as quickly as possible.
#
# This assignment will be due by 5 PM next Monday, April 6th.

# %%
# Load the re module

import re

# %%
# Create a file object to read from the covid data file
# This file contains cumulative case counts and deaths from 
# covid-19 for every country in the US. It was current as of
# March 30th.

file = open("covidData_3.30.20.txt","r")

# %%
# Find all parishes from Louisiana in this file.
# You should make a list that contains only the parish
# names. This list can be created with a single command.
# Be careful to include ALL the parishes in your search.

matches = re.findall(r"(?<=\d\,)(.*?)(?=\,Louisiana)",file.read())

# %%
# Close the covid data file object

file.close()

# %%
# Print out the Louisiana search results

print(matches)
# Out:
# ['Jefferson', 'Jefferson', 'Orleans', 'Caddo', 'Jefferson', 'Orleans', 'Caddo', 'Jefferson', 'Orleans', 'Caddo', 'Jefferson', 'Orleans', 'St. Charles', 'St. Tammany', 'Terrebonne', 'Bossier', 'Caddo', 'Jefferson', 'Lafourche', 'Orleans', 'St. Charles', 'St. John the Baptist', 'St. Tammany', 'Terrebonne', 'Bossier', 'Caddo', 'Jefferson', 'Lafourche', 'Orleans', 'St. Bernard', 'St. Charles', 'St. John the Baptist', 'St. Tammany', 'Terrebonne', 'Ascension', 'Bossier', 'Caddo', 'Jefferson', 'Lafourche', 'Orleans', 'St. Bernard', 'St. Charles', 'St. John the Baptist', 'St. Tammany', 'Terrebonne', 'Ascension', 'Bossier', 'Caddo', 'East Baton Rouge', 'Jefferson', 'Lafourche', 'Orleans', 'St. Bernard', 'St. Charles', 'St. John the Baptist', 'St. Tammany', 'Terrebonne', 'Washington', 'Ascension', 'Bossier', 'Caddo', 'East Baton Rouge', 'Jefferson', 'Lafourche', 'Orleans', 'St. Bernard', 'St. Charles', 'St. John the Baptist', 'St. Tammany', 'Terrebonne', 'Unknown', 'Washington', 'Ascension', 'Assumption', 'Bossier', 'Caddo', 'Calcasieu', 'East Baton Rouge', 'Iberia', 'Iberville', 'Jefferson', 'Lafayette', 'Lafourche', 'Livingston', 'Orleans', 'Plaquemines', 'St. Bernard', 'St. Charles', 'St. James', 'St. John the Baptist', 'St. Landry', 'St. Tammany', 'Terrebonne', 'Unknown', 'Washington', 'Webster', 'West Baton Rouge', 'Ascension', 'Assumption', 'Bossier', 'Caddo', 'Calcasieu', 'Catahoula', 'De Soto', 'East Baton Rouge', 'Iberia', 'Iberville', 'Jefferson', 'Lafayette', 'Lafourche', 'Livingston', 'Orleans', 'Plaquemines', 'Rapides', 'St. Bernard', 'St. Charles', 'St. James', 'St. John the Baptist', 'St. Landry', 'St. Tammany', 'Tangipahoa', 'Terrebonne', 'Unknown', 'Washington', 'Webster', 'West Baton Rouge', 'Ascension', 'Assumption', 'Avoyelles', 'Beauregard', 'Bienville', 'Bossier', 'Caddo', 'Calcasieu', 'Catahoula', 'Claiborne', 'De Soto', 'East Baton Rouge', 'Evangeline', 'Iberia', 'Iberville', 'Jefferson', 'Lafayette', 'Lafourche', 'Livingston', 'Orleans', 'Ouachita', 'Plaquemines', 'Rapides', 'St. Bernard', 'St. Charles', 'St. James', 'St. John the Baptist', 'St. Landry', 'St. Mary', 'St. Tammany', 'Tangipahoa', 'Terrebonne', 'Unknown', 'Washington', 'Webster', 'West Baton Rouge', 'Acadia', 'Ascension', 'Assumption', 'Avoyelles', 'Beauregard', 'Bienville', 'Bossier', 'Caddo', 'Calcasieu', 'Catahoula', 'Claiborne', 'De Soto', 'East Baton Rouge', 'Evangeline', 'Iberia', 'Iberville', 'Jefferson', 'Lafayette', 'Lafourche', 'Livingston', 'Orleans', 'Ouachita', 'Plaquemines', 'Rapides', 'St. Bernard', 'St. Charles', 'St. James', 'St. John the Baptist', 'St. Landry', 'St. Mary', 'St. Tammany', 'Tangipahoa', 'Terrebonne', 'Unknown', 'Washington', 'Webster', 'West Baton Rouge', 'Acadia', 'Allen', 'Ascension', 'Assumption', 'Avoyelles', 'Beauregard', 'Bienville', 'Bossier', 'Caddo', 'Calcasieu', 'Catahoula', 'Claiborne', 'De Soto', 'East Baton Rouge', 'Evangeline', 'Grant', 'Iberia', 'Iberville', 'Jefferson', 'Lafayette', 'Lafourche', 'Lincoln', 'Livingston', 'Natchitoches', 'Orleans', 'Ouachita', 'Plaquemines', 'Rapides', 'Richland', 'St. Bernard', 'St. Charles', 'St. James', 'St. John the Baptist', 'St. Landry', 'St. Martin', 'St. Mary', 'St. Tammany', 'Tangipahoa', 'Terrebonne', 'Unknown', 'Washington', 'Webster', 'West Baton Rouge', 'Acadia', 'Allen', 'Ascension', 'Assumption', 'Avoyelles', 'Beauregard', 'Bienville', 'Bossier', 'Caddo', 'Calcasieu', 'Catahoula', 'Claiborne', 'De Soto', 'East Baton Rouge', 'Evangeline', 'Grant', 'Iberia', 'Iberville', 'Jefferson', 'Lafayette', 'Lafourche', 'Lincoln', 'Livingston', 'Natchitoches', 'Orleans', 'Ouachita', 'Plaquemines', 'Rapides', 'Richland', 'St. Bernard', 'St. Charles', 'St. James', 'St. John the Baptist', 'St. Landry', 'St. Martin', 'St. Mary', 'St. Tammany', 'Tangipahoa', 'Terrebonne', 'Unknown', 'Vernon', 'Washington', 'Webster', 'West Baton Rouge', 'Acadia', 'Allen', 'Ascension', 'Assumption', 'Avoyelles', 'Beauregard', 'Bienville', 'Bossier', 'Caddo', 'Calcasieu', 'Catahoula', 'Clai ...

# %%
# Create a dictionary that has the Louisiana parish 
# names as keys and the number of times they appear 
# in the data file as values.

# Hint: You can test if a dictionary does or does not
# contain a certain key using:
# myKey in myDict --or-- myKey not in myDict

covid = {}

for parish in matches:
    if (parish in covid):
        covid[parish] += 1
    else:
        covid[parish] = 1

# %%
# Using your dictionary, figure out which of these parishes has
# the most entries in the file. The one with the most entries
# had the earliest observed covid case.
# Jefferson, Orleans, East Baton Rouge, Plaquemines

max(covid, key=covid.get)
# Out:
# 'Jefferson'

# %%
# Figure out how many parishes are in the dictionary. How does 
# this compare to the total number of parishes in the state?

len(covid)
# Out:
# 60

# %%
# Now, reopen the data file and use a regex search to find the first instance 
# where a Louisiana parish recorded a covid-19 death. This will be the first 
# line in the file that includes Louisiana and has a death count >0. After 
# your search, print the date and the parish. Be sure to also close the input file.
# Example output: ZZZZ parish reported the first covid-19 death in Louisiana on 2020-ZZ-ZZ

file = open("covidData_3.30.20.txt","r")

match1 = re.search(r"Louisiana\,\d*\,\d*\,1\n",file.read())

match2 = re.findall(r"(2020\-\d\d\-\d\d\,)(.*)(?=\,Louisiana\,\d*\,\d*\,1\n)",file.read())

print(match1)
print(match2)

#proceed as if match2 works as intended where it is a list of all Louisiana parishes with 1 death and their corresponding dates

print(match2[0[1]],"parish reported the first covid-19 death in Louisiana on ",match[0[0]])

file.close()
# Out:
# <_sre.SRE_Match object; span=(82077, 82098), match='Louisiana,22071,53,1\n'>
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-7fb7ccd47ecf> in <module>()
#      16 #proceed as if match2 works as intended where it is a list of all Louisiana parishes with 1 death and their corresponding dates
#      17
# ---> 18 print(match2[0[1]],"parish reported the first covid-19 death in Louisiana on ",match[0[0]])
#      19
#      20 file.close()
#
# TypeError: 'int' object is not subscriptable

# %%
# Now we need to create a new file that only has records from Louisiana. 
# Extract the lines that pertain to Louisiana and write them to a new file.

file = open("covidData_3.30.20.txt","r")

match3 = re.findall(r"(2020\-\d\d\-\d\d\,.*\,Louisiana\,\d*\,\d*\,\d*)(?=\n)",file.read())

file2 = open('covidLA.txt','w')

for element in match3:
    file2.write(element)
    file2.write('\n')

file2.close()

file.close
# Out:
# <function TextIOWrapper.close>

# %%
# Lastly, let's imagine that we want to do further downstream analyses with
# the Louisiana data, but our downstream analyses require some formatting chanages.
# Read in the lines from your newly created file with only Louisiana records, reformat them, 
# and create a separate file to hold the newly formatted information. Specifically, the 
# dates in the file should be reformatted from looking like this (2020-MM-DD) to looking 
# like this (MM.DD.2020). Also, the fips codes (in the 4th column) should be removed, and
# Louisiana should be abbreviated as LA. So, this file should end up with entries that look
# like this: 03.25.2020,Morehouse,LA,1,0

file = open('covidLA.txt','r')

match4 = re.sub(r"(2020)(\-)(\d\d)(\-)(\d\d)(\,.*\,)(Louisiana)(\,\d*)",r"\3.\5.\1\6LA",file.read())

print(match4)

file2 = open('covidLAreformat.txt','w')

for element in match4:
    file2.write(element)
    file2.write('\n')
    
file.close()
file2.close()
# Out:
# 03.09.2020,Jefferson,LA,1,0
# 03.10.2020,Jefferson,LA,1,0
# 03.10.2020,Orleans,LA,5,0
# 03.11.2020,Caddo,LA,1,0
# 03.11.2020,Jefferson,LA,1,0
# 03.11.2020,Orleans,LA,11,0
# 03.12.2020,Caddo,LA,1,0
# 03.12.2020,Jefferson,LA,1,0
# 03.12.2020,Orleans,LA,12,0
# 03.13.2020,Caddo,LA,1,0
# 03.13.2020,Jefferson,LA,3,0
# 03.13.2020,Orleans,LA,28,0
# 03.13.2020,St. Charles,LA,1,0
# 03.13.2020,St. Tammany,LA,2,0
# 03.13.2020,Terrebonne,LA,1,0
# 03.14.2020,Bossier,LA,1,0
# 03.14.2020,Caddo,LA,2,0
# 03.14.2020,Jefferson,LA,11,0
# 03.14.2020,Lafourche,LA,1,0
# 03.14.2020,Orleans,LA,53,1
# 03.14.2020,St. Charles,LA,2,0
# 03.14.2020,St. John the Baptist,LA,1,0
# 03.14.2020,St. Tammany,LA,4,0
# 03.14.2020,Terrebonne,LA,2,0
# 03.15.2020,Bossier,LA,1,0
# 03.15.2020,Caddo,LA,2,0
# 03.15.2020,Jefferson,LA,14,0
# 03.15.2020,Lafourche,LA,1,0
# 03.15.2020,Orleans,LA,75,2
# 03.15.2020,St. Bernard,LA,1,0
# 03.15.2020,St. Charles,LA,2,0
# 03.15.2020,St. John the Baptist,LA,1,0
# 03.15.2020,St. Tammany,LA,4,0
# 03.15.2020,Terrebonne,LA,2,0
# 03.16.2020,Ascension,LA,1,0
# 03.16.2020,Bossier,LA,1,0
# 03.16.2020,Caddo,LA,3,0
# 03.16.2020,Jefferson,LA,21,0
# 03.16.2020,Lafourche,LA,2,0
# 03.16.2020,Orleans,LA,95,3
# 03.16.2020,St. Bernard,LA,2,0
# 03.16.2020,St. Charles,LA,3,0
# 03.16.2020,St. John the Baptist,LA,1,0
# 03.16.2020,St. Tammany,LA,6,0
# 03.16.2020,Terrebonne,LA,2,0
# 03.17.2020,Ascension,LA,1,0
# 03.17.2020,Bossier,LA,1,0
# 03.17.2020,Caddo,LA,4,0
# 03.17.2020,East Baton Rouge,LA,1,0
# 03.17.2020,Jefferson,LA,35,0
# 03.17.2020,Lafourche,LA,2,0
# 03.17.2020,Orleans,LA,136,5
# 03.17.2020,St. Bernard,LA,2,0
# 03.17.2020,St. Charles,LA,3,0
# 03.17.2020,St. John the Baptist,LA,1,0
# 03.17.2020,St. Tammany,LA,6,0
# 03.17.2020,Terrebonne,LA,3,0
# 03.17.2020,Washington,LA,1,0
# 03.18.2020,Ascension,LA,1,0
# 03.18.2020,Bossier,LA,2,0
# 03.18.2020,Caddo,LA,6,0
# 03.18.2020,East Baton Rouge,LA,3,0
# 03.18.2020,Jefferson,LA,45,1
# 03.18.2020,Lafourche,LA,3,0
# 03.18.2020,Orleans,LA,196,6
# 03.18.2020,St. Bernard,LA,3,0
# 03.18.2020,St. Charles,LA,3,0
# 03.18.2020,St. John the Baptist,LA,2,0
# 03.18.2020,St. Tammany,LA,10,0
# 03.18.2020,Terrebonne,LA,3,0
# 03.18.2020,Unknown,LA,2,0
# 03.18.2020,Washington,LA,1,0
# 03.19.2020,Ascension,LA,2,0
# 03.19.2020,Assumption,LA,1,0
# 03.19.2020,Bossier,LA,4,0
# 03.19.2020,Caddo,LA,10,0
# 03.19.2020,Calcasieu,LA,1,0
# 03.19.2020,East Baton Rouge,LA,6,0
# 03.19.2020,Iberia,LA,1,0
# 03.19.2020,Iberville,LA,1,0
# 03.19.2020,Jefferson,LA,69,1
# 03.19.2020,Lafayette,LA,3,0
# 03.19.2020,Lafourche,LA,4,0
# 03.19.2020,Livingston,LA,1,0
# 03.19.2020,Orleans,LA,252,8
# 03.19.2020,Plaquemines,LA,1,0
# 03.19.2020,St. Bernard,LA,4,0
# 03.19.2020,St. Charles,LA,4,0
# 03.19.2020,St. James,LA,1,1
# 03.19.2020,St. John the Baptist,LA,3,0
# 03.19.2020,St. Landry,LA,2,0
# 03.19.2020,St. Tammany,LA,10,0
# 03.19.2020,Terrebonne,LA,4,0
# 03.19.2020,Unknown,LA,3,0
# 03.19.2020,Washington,LA,2,0
# 03.19.2020,Webster,LA,1,0
# 03.19.2020,West Baton Rouge,LA,2,0
# 03.20.2020,Ascension,LA,3,0
# 03.20.2020,Assumption,LA,1,0
# 03.20.2020,Bossier,LA,5,0
# 03.20.2020,Caddo,LA,12,0
# 03.20.2020,Calcasieu,LA,3,0
# 03.20.2020,Catahoula,LA,1,0
# 03.20.2020,De Soto,LA,2,0
# 03.20.2020,East Baton Rouge,LA,7,0
# 03.20.2020,Iberia,LA,2,0
# 03.20.2020,Iberville,LA,1,0
# 03.20.2020,Jefferson,LA,104,1
# 03.20.2020,Lafayette,LA,6,0
# 03.20.2020,Lafourche,LA,5,0
# 03.20.2020,Livingston,LA,1,0
# 03.20.2020,Orleans,LA,329,8
# 03.20.2020,Plaquemines,LA,1,0
# 03.20.2020,Rapides,LA,2,0
# 03.20.2020,St. Bernard,LA,5,0
# 03.20.2020,St. Charles,LA,7,0
# 03.20.2020,St. James,LA,1,1
# 03.20.2020,St. John the Baptist,LA,6,0
# 03.20.2020,St. Landry,LA,2,0
# 03.20.2020,St. Tammany,LA,12,0
# 03.20.2020,Tangipahoa,LA,1,0
# 03.20.2020,Terrebonne,LA,7,0
# 03.20.2020,Unknown,LA,5,0
# 03.20.2020,Washington,LA,2,0
# 03.20.2020,Webster,LA,1,0
# 03.20.2020,West Baton Rouge,LA,3,0
# 03.21.2020,Ascension,LA,12,0
# 03.21.2020,Assumption,LA,1,0
# 03.21.2020,Avoyelles,LA,1,0
# 03.21.2020,Beauregard,LA,1,0
# 03.21.2020,Bienville,LA,1,0
# 03.21.2020,Bossier,LA,5,0
# 03.21.2020,Caddo,LA,15,0
# 03.21.2020,Calcasieu,LA,4,0
# 03.21.2020,Catahoula,LA,1,0
# 03.21.2020,Claiborne,LA,1,0
# 03.21.2020,De Soto,LA,2,0
# 03.21.2020,East Baton Rouge,LA,18,0
# 03.21.2020,Evangeline,LA,2,0
# 03.21.2020,Iberia,LA,3,0
# 03.21.2020,Iberville,LA,1,0
# 03.21.2020,Jefferson,LA,166,2
# 03.21.2020,Lafayette,LA,6,0
# 03.21.2020,Lafourche,LA,11,0
# 03.21.2020,Livingston,LA,2,0
# 03.21.2020,Orleans,LA,418,13
# 03.21.2020,Ouachita,LA,2,0
# 03.21.2020,Plaquemines,LA,4,0
# 03.21.2020,Rapides,LA,2,0
# 03.21.2020,St. Bernard,LA,12,0
# 03.21.2020,St. Charles,LA,7,0
# 03.21.2020,St. James,LA,1,1
# 03.21.2020,St. John the Baptist,LA,9,0
# 03.21.2020,St. Landry,LA,3,0
# 03.21.2020,St. Mary,LA,1,0
# 03.21.2020,St. Tammany,LA,22,0
# 03.21.2020,Tangipahoa,LA,3,0
# 03.21.2020,Terrebonne,LA,11,0
# 03.21.2020,Unknown,LA,9,0
# 03.21.2020,Washington,LA,2,0
# 03.21.2020,Webster,LA,1,0
# 03.21.2020,West Baton Rouge,LA,3,0
# 03.22.2020,Acadia,LA,1,0
# 03.22.2020,Ascension,LA,17,0
# 03.22.2020,Assumption,LA,1,0
# 03.22.2020,Avoyelles,LA,1,0
# 03.22.2020,Beauregard,LA,1,0
# 03.22.2020,Bienville,LA,1,0
# 03.22.2020,Bossier,LA,5,0
# 03.22.2020,Caddo,LA,16,0
# 03.22.2020,Calcasieu,LA,4,0
# 03.22.2020,Catahoula,LA,1,1
# 03.22.2020,Claiborne,LA,1,0
# 03.22.2020,De Soto,LA,2,0
# 03.22.2020,East Baton Rouge,LA,20,0
# 03.22.2020,Evangeline,LA,2,0
# 03.22.2020,Iberia,LA,3,0
# 03.22.2020,Iberville,LA,1,0
# 03.22.2020,Jefferson,LA,184,3
# 03.22.2020,Lafayette,LA,6,0
# 03.22.2020,Lafourche,LA,12,0
# 03.22.2020,Livingston,LA,2,0
# 03.22.2020,Orleans,LA,451,15
# 03.22.2020,Ouachita,LA,4,0
# 03.22.2020,Plaquemines,LA,5,0
# 03.22.2020,Rapides,LA,3,0
# 03.22.2020,St. Bernard,LA,13,0
# 03.22.2020,St. Charles,LA,8,0
# 03.22.2020,St. James,LA,1,1
# 03.22.2020,St. John the Baptist,LA,10,0
# 03.22.2020,St. Landry,LA,3,0
# 03.22.2020,St. Mary,LA,1,0
# 03.22.2020,St. Tammany,LA,25,0
# 03.22.2020,Tangipahoa,LA,3,0
# 03.22.2020,Terrebonne,LA,12,0
# 03.22.2020,Unknown,LA,11,0
# 03.22.2020,Washington,LA,2,0
# 03.22.2020,Webster,LA,1,0
# 03.22.2020,West Baton Rouge,LA,3,0
# 03.23.2020,Acadia,LA,1,0
# 03.23.2020,Allen,LA,2,0
# 03.23.2020,Ascension,LA,26,1
# 03.23.2020,Assumption,LA,1,0
# 03.23.2020,Avoyelles,LA,2,0
# 03.23.2020,Beauregard,LA,1,0
# 03.23.2020,Bienville,LA,1,0
# 03.23.2020,Bossier,LA,12,0
# 03.23.2020,Caddo,LA,34,0
# 03.23.2020,Calcasieu,LA,4,0
# 03.23.2020,Catahoula,LA,1,1
# 03.23.2020,Claiborne,LA,2,0
# 03.23.2020,De Soto,LA,5,0
# 03.23.2020,East Baton Rouge,LA,43,1
# 03.23.2020,Evangeline,LA,2,0
# 03.23.2020,Grant,LA,1,0
# 03.23.2020,Iberia,LA,4,0
# 03.23.2020,Iberville,LA,8,0
# 03.23.2020,Jefferson,LA,252,5
# 03.23.2020,Lafayette,LA,11,0
# 03.23.2020,Lafourche,LA,15,0
# 03.23.2020,Lincoln,LA,2,0
# 03.23.2020,Livingston,LA,5,0
# 03.23.2020,Natchitoches,LA,2,0
# 03.23.2020,Orleans,LA,567,20
# 03.23.2020,Ouachita,LA,7,1
# 03.23.2020,Plaquemines,LA,8,0
# 03.23.2020,Rapides,LA,8,1
# 03.23.2020,Richland,LA,1,0
# 03.23.2020,St. Bernard,LA,15,0
# 03.23.2020,St. Charles,LA,15,0
# 03.23.2020,St. James,LA,8,1
# 03.23.2020,St. John the Baptist,LA,16,0
# 03.23.2020,St. Landry,LA,3,0
# 03.23.2020,St. Martin,LA,1,0
# 03.23.2020,St. Mary,LA,1,0
# 03.23.2020,St. Tammany,LA,47,0
# 03.23.2020,Tangipahoa,LA,3,0
# 03.23.2020,Terrebonne,LA,14,0
# 03.23.2020,Unknown,LA,12,0
# 03.23.2020,Washington,LA,2,1
# 03.23.2020,Webster,LA,3,1
# 03.23.2020,West Baton Rouge,LA,4,1
# 03.24.2020,Acadia,LA,2,0
# 03.24.2020,Allen,LA,2,0
# 03.24.2020,Ascension,LA,36,1
# 03.24.2020,Assumption,LA,2,0
# 03.24.2020,Avoyelles,LA,3,0
# 03.24.2020,Beauregard,LA,2,0
# 03.24.2020,Bienville,LA,1,0
# 03.24.2020,Bossier,LA,12,0
# 03.24.2020,Caddo,LA,40,0
# 03.24.2020,Calcasieu,LA,5,1
# 03.24.2020,Catahoula,LA,1,1
# 03.24.2020,Claiborne,LA,2,0
# 03.24.2020,De Soto,LA,6,0
# 03.24.2020,East Baton Rouge,LA,58,2
# 03.24.2020,Evangeline,LA,2,0
# 03.24.2020,Grant,LA,1,0
# 03.24.2020,Iberia,LA,4,0
# 03.24.2020,Iberville,LA,14,1
# 03.24.2020,Jefferson,LA,293,6
# 03.24.2020,Lafayette,LA,12,0
# 03.24.2020,Lafourche,LA,16,0
# 03.24.2020,Lincoln,LA,2,0
# 03.24.2020,Livingston,LA,6,0
# 03.24.2020,Natchitoches,LA,2,0
# 03.24.2020,Orleans,LA,675,26
# 03.24.2020,Ouachita,LA,7,1
# 03.24.2020,Plaquemines,LA,8,0
# 03.24.2020,Rapides,LA,10,1
# 03.24.2020,Richland,LA,1,0
# 03.24.2020,St. Bernard,LA,19,0
# 03.24.2020,St. Charles,LA,15,0
# 03.24.2020,St. James,LA,9,1
# 03.24.2020,St. John the Baptist,LA,21,0
# 03.24.2020,St. Landry,LA,3,0
# 03.24.2020,St. Martin,LA,1,0
# 03.24.2020,St. Mary,LA,2,0
# 03.24.2020,St. Tammany,LA,52,1
# 03.24.2020,Tangipahoa,LA,4,0
# 03.24.2020,Terrebonne,LA,14,0
# 03.24.2020,Unknown,LA,12,1
# 03.24.2020,Vernon,LA,2,0
# 03.24.2020,Washington,LA,3,1
# 03.24.2020,Webster,LA,3,1
# 03.24.2020,West Baton Rouge,LA,5,1
# 03.25.2020,Acadia,LA,2,0
# 03.25.2020,Allen,LA,2,0
# 03.25.2020,Ascension,LA,65,1
# 03.25.2020,Assumption,LA,2,0
# 03.25.2020,Avoyelles,LA,5,0
# 03.25.2020,Beauregard,LA,3,0
# 03.25.2020,Bienville,LA,1,1
# 03.25.2020,Bossier,LA,25,0
# 03.25.2020,Caddo,LA,93,0
# 03.25.2020,Calcasieu,LA,11,1
# 03.25.2020,Catahoula,LA,1,1
# 03.25.2020,Claiborne,LA,2,0
# 03.25.2020,De Soto,LA,8,0
# 03.25.2020,East Baton Rouge,LA,75,3
# 03.25.2020,Evangeline,LA,2,0
# 03.25.2020,Grant,LA,1,0
# 03.25.2020,Iberia,LA,4,0
# 03.25.2020,Iberville,LA,14,1
# 03.25.2020,Jackson,LA,1,0
# 03.25.2020,Jefferson,LA,359,7
# 03.25.2020,Jefferson Davis,LA,1,0
# 03.25.2020,Lafayette,LA,20,0
# 03.25.2020,Lafourche,LA,18,1
# 03.25.2020,Lincoln,LA,2,0
# 03.25.2020,Livingston,LA,6,0
# 03.25.2020,Morehouse,LA,1,0
# 03.25.2020,Natchitoches,LA,2,0
# 03.25.2020,Orleans,LA,827,37
# 03.25.2020,Ouachita,LA,10,1
# 03.25.2020,Plaquemines,LA,9,0
# 03.25.2020,Rapides,LA,14,1
# 03.25.2020,Richland,LA,1,0
# 03.25.2020,St. Bernard,LA,23,1
# 03.25.2020,St. Charles,LA,17,1
# 03.25.2020,St. James,LA,14,1
# 03.25.2020,St. John the Baptist,LA,27,2
# 03.25.2020,St. Landry,LA,4,0
# 03.25.2020,St. Martin,LA,1,0
# 03.25.2020,St. Mary,LA,5,0
# 03.25.2020,St. Tammany,LA,67,1
# 03.25.2020,Tangipahoa,LA,5,0
# 03.25.2020,Terrebonne,LA,15,0
# 03.25.2020,Union,LA,2,0
# 03.25.2020,Unknown,LA,12,1
# 03.25.2020,Vernon,LA,2,0
# 03.25.2020,Washington,LA,4,1
# 03.25.2020,Webster,LA,5,1
# 03.25.2020,West Baton Rouge,LA,7,1
# 03.25.2020,Winn,LA,1,0
# 03.26.2020,Acadia,LA,3,0
# 03.26.2020,Allen,LA,5,0
# 03.26.2020,Ascension,LA,91,1
# 03.26.2020,Assumption,LA,5,0
# 03.26.2020,Avoyelles,LA,7,0
# 03.26.2020,Beauregard,LA,3,0
# 03.26.2020,Bienville,LA,1,1
# 03.26.2020,Bossier,LA,32,0
# 03.26.2020,Caddo,LA,115,1
# 03.26.2020,Calcasieu,LA,15,1
# 03.26.2020,Catahoula,LA,1,1
# 03.26.2020,Claiborne,LA,2,0
# 03.26.2020,De Soto,LA,11,1
# 03.26.2020,East Baton Rouge,LA,105,4
# 03.26.2020,East Feliciana,LA,4,0
# 03.26.2020,Evangeline,LA,2,0
# 03.26.2020,Grant,LA,1,0
# 03.26.2020,Iberia,LA,4,0
# 03.26.2020,Iberville,LA,17,1
# 03.26.2020,Jackson,LA,1,0
# 03.26.2020,Jefferson,LA,458,12
# 03.26.2020,Jefferson Davis,LA,1,0
# 03.26.2020,LaSalle,LA,1,0
# 03.26.2020,Lafayette,LA,30,0
# 03.26.2020,Lafourche,LA,28,1
# 03.26.2020,Lincoln,LA,3,0
# 03.26.2020,Livingston,LA,11,0
# 03.26.2020,Madison,LA,1,0
# 03.26.2020,Morehouse,LA,3,0
# 03.26.2020,Natchitoches,LA,2,0
# 03.26.2020,Orleans,LA,997,46
# 03.26.2020,Ouachita,LA,19,1
# 03.26.2020,Plaquemines,LA,13,0
# 03.26.2020,Pointe Coupee,LA,1,0
# 03.26.2020,Rapides,LA,25,1
# 03.26.2020,Richland,LA,1,0
# 03.26.2020,St. Bernard,LA,28,1
# 03.26.2020,St. Charles,LA,22,2
# 03.26.2020,St. James,LA,29,1
# 03.26.2020,St. John the Baptist,LA,38,2
# 03.26.2020,St. Landry,LA,5,0
# 03.26.2020,St. Martin,LA,2,0
# 03.26.2020,St. Mary,LA,5,0
# 03.26.2020,St. Tammany,LA,89,1
# 03.26.2020,Tangipahoa,LA,7,0
# 03.26.2020,Terrebonne,LA,21,0
# 03.26.2020,Union,LA,2,0
# 03.26.2020,Unknown,LA,13,1
# 03.26.2020,Vermilion,LA,1,0
# 03.26.2020,Vernon,LA,2,0
# 03.26.2020,Washington,LA,6,1
# 03.26.2020,Webster,LA,8,1
# 03.26.2020,West Baton Rouge,LA,8,1
# 03.26.2020,Winn,LA,1,0
# 03.27.2020,Acadia,LA,8,1
# 03.27.2020,Allen,LA,5,0
# 03.27.2020,Ascension,LA,90,1
# 03.27.2020,Assumption,LA,8,0
# 03.27.2020,Avoyelles,LA,10,0
# 03.27.2020,Beauregard,LA,4,0
# 03.27.2020,Bienville,LA,1,1
# 03.27.2020,Bossier,LA,37,0
# 03.27.2020,Caddo,LA,140,2
# 03.27.2020,Calcasieu,LA,22,1
# 03.27.2020,Catahoula,LA,1,1
# 03.27.2020,Claiborne,LA,3,0
# 03.27.2020,De Soto,LA,13,1
# 03.27.2020,East Baton Rouge,LA,124,4
# 03.27.2020,East Feliciana,LA,5,0
# 03.27.2020,Evangeline,LA,4,0
# 03.27.2020,Grant,LA,1,0
# 03.27.2020,Iberia,LA,4,0
# 03.27.2020,Iberville,LA,20,1
# 03.27.2020,Jackson,LA,3,0
# 03.27.2020,Jefferson,LA,548,24
# 03.27.2020,Jefferson Davis,LA,1,0
# 03.27.2020,LaSalle,LA,1,0
# 03.27.2020,Lafayette,LA,44,0
# 03.27.2020,Lafourche,LA,30,2
# 03.27.2020,Lincoln,LA,7,0
# 03.27.2020,Livingston,LA,11,0
# 03.27.2020,Madison,LA,1,0
# 03.27.2020,Morehouse,LA,2,0
# 03.27.2020,Natchitoches,LA,2,0
# 03.27.2020,Orleans,LA,1170,57
# 03.27.2020,Ouachita,LA,25,1
# 03.27.2020,Plaquemines,LA,16,2
# 03.27.2020,Pointe Coupee,LA,1,0
# 03.27.2020,Rapides,LA,26,1
# 03.27.2020,Richland,LA,2,0
# 03.27.2020,St. Bernard,LA,31,1
# 03.27.2020,St. Charles,LA,23,2
# 03.27.2020,St. James,LA,40,3
# 03.27.2020,St. John the Baptist,LA,41,3
# 03.27.2020,St. Landry,LA,10,0
# 03.27.2020,St. Martin,LA,10,3
# 03.27.2020,St. Mary,LA,6,0
# 03.27.2020,St. Tammany,LA,111,2
# 03.27.2020,Tangipahoa,LA,7,0
# 03.27.2020,Terrebonne,LA,23,1
# 03.27.2020,Union,LA,4,0
# 03.27.2020,Unknown,LA,16,1
# 03.27.2020,Vermilion,LA,2,0
# 03.27.2020,Vernon,LA,2,0
# 03.27.2020,Washington,LA,8,1
# 03.27.2020,Webster,LA,9,1
# 03.27.2020,West Baton Rouge,LA,11,1
# 03.27.2020,West Feliciana,LA,1,0
# 03.27.2020,Winn,LA,1,0
# 03.28.2020,Acadia,LA,9,1
# 03.28.2020,Allen,LA,7,0
# 03.28.2020,Ascension,LA,107,1
# 03.28.2020,Assumption,LA,8,0
# 03.28.2020,Avoyelles,LA,12,0
# 03.28.2020,Beauregard,LA,4,0
# 03.28.2020,Bienville,LA,3,1
# 03.28.2020,Bossier,LA,45,0
# 03.28.2020,Caddo,LA,189,2
# 03.28.2020,Calcasieu,LA,28,1
# 03.28.2020,Catahoula,LA,1,1
# 03.28.2020,Claiborne,LA,4,0
# 03.28.2020,De Soto,LA,21,1
# 03.28.2020,East Baton Rouge,LA,153,4
# 03.28.2020,East Carroll,LA,1,0
# 03.28.2020,East Feliciana,LA,6,0
# 03.28.2020,Evangeline,LA,4,0
# 03.28.2020,Franklin,LA,4,0
# 03.28.2020,Grant,LA,1,0
# 03.28.2020,Iberia,LA,9,0
# 03.28.2020,Iberville,LA,21,1
# 03.28.2020,Jackson,LA,2,0
# 03.28.2020,Jefferson,LA,744,26
# 03.28.2020,Jefferson Davis,LA,1,0
# 03.28.2020,LaSalle,LA,2,0
# 03.28.2020,Lafayette,LA,48,1
# 03.28.2020,Lafourche,LA,34,2
# 03.28.2020,Lincoln,LA,6,0
# 03.28.2020,Livingston,LA,12,0
# 03.28.2020,Madison,LA,1,0
# 03.28.2020,Morehouse,LA,2,0
# 03.28.2020,Natchitoches,LA,2,0
# 03.28.2020,Orleans,LA,1298,70
# 03.28.2020,Ouachita,LA,34,1
# 03.28.2020,Plaquemines,LA,19,2
# 03.28.2020,Pointe Coupee,LA,2,0
# 03.28.2020,Rapides,LA,37,1
# 03.28.2020,Richland,LA,2,0
# 03.28.2020,St. Bernard,LA,43,2
# 03.28.2020,St. Charles,LA,30,2
# 03.28.2020,St. James,LA,48,3
# 03.28.2020,St. John the Baptist,LA,54,3
# 03.28.2020,St. Landry,LA,10,0
# 03.28.2020,St. Martin,LA,13,3
# 03.28.2020,St. Mary,LA,7,0
# 03.28.2020,St. Tammany,LA,134,2
# 03.28.2020,Tangipahoa,LA,10,0
# 03.28.2020,Terrebonne,LA,26,1
# 03.28.2020,Union,LA,7,0
# 03.28.2020,Unknown,LA,12,2
# 03.28.2020,Vermilion,LA,3,1
# 03.28.2020,Vernon,LA,2,0
# 03.28.2020,Washington,LA,10,1
# 03.28.2020,Webster,LA,9,1
# 03.28.2020,West Baton Rouge,LA,12,1
# 03.28.2020,West Feliciana,LA,4,0
# 03.28.2020,Winn,LA,1,0
# 03.29.2020,Acadia,LA,9,1
# 03.29.2020,Allen,LA,9,1
# 03.29.2020,Ascension,LA,139,2
# 03.29.2020,Assumption,LA,14,0
# 03.29.2020,Avoyelles,LA,13,0
# 03.29.2020,Beauregard,LA,4,0
# 03.29.2020,Bienville,LA,3,1
# 03.29.2020,Bossier,LA,56,0
# 03.29.2020,Caddo,LA,219,5
# 03.29.2020,Calcasieu,LA,35,1
# 03.29.2020,Caldwell,LA,1,0
# 03.29.2020,Catahoula,LA,1,1
# 03.29.2020,Claiborne,LA,4,0
# 03.29.2020,De Soto,LA,25,1
# 03.29.2020,East Baton Rouge,LA,164,7
# 03.29.2020,East Carroll,LA,1,0
# 03.29.2020,East Feliciana,LA,8,0
# 03.29.2020,Evangeline,LA,4,0
# 03.29.2020,Franklin,LA,4,0
# 03.29.2020,Grant,LA,2,0
# 03.29.2020,Iberia,LA,11,0
# 03.29.2020,Iberville,LA,22,1
# 03.29.2020,Jackson,LA,2,0
# 03.29.2020,Jefferson,LA,761,28
# 03.29.2020,Jefferson Davis,LA,2,0
# 03.29.2020,LaSalle,LA,2,0
# 03.29.2020,Lafayette,LA,50,1
# 03.29.2020,Lafourche,LA,36,2
# 03.29.2020,Lincoln,LA,7,0
# 03.29.2020,Livingston,LA,15,0
# 03.29.2020,Madison,LA,1,0
# 03.29.2020,Morehouse,LA,2,0
# 03.29.2020,Natchitoches,LA,2,0
# 03.29.2020,Orleans,LA,1350,73
# 03.29.2020,Ouachita,LA,41,1
# 03.29.2020,Plaquemines,LA,20,2
# 03.29.2020,Pointe Coupee,LA,2,0
# 03.29.2020,Rapides,LA,41,1
# 03.29.2020,Red River,LA,1,0
# 03.29.2020,Richland,LA,2,0
# 03.29.2020,Sabine,LA,1,0
# 03.29.2020,St. Bernard,LA,45,2
# 03.29.2020,St. Charles,LA,31,2
# 03.29.2020,St. James,LA,55,3
# 03.29.2020,St. John the Baptist,LA,57,5
# 03.29.2020,St. Landry,LA,10,0
# 03.29.2020,St. Martin,LA,13,3
# 03.29.2020,St. Mary,LA,7,0
# 03.29.2020,St. Tammany,LA,138,3
# 03.29.2020,Tangipahoa,LA,10,0
# 03.29.2020,Terrebonne,LA,29,1
# 03.29.2020,Union,LA,9,0
# 03.29.2020,Unknown,LA,12,1
# 03.29.2020,Vermilion,LA,2,1
# 03.29.2020,Vernon,LA,2,0
# 03.29.2020,Washington,LA,12,1
# 03.29.2020,Webster,LA,9,1
# 03.29.2020,West Baton Rouge,LA,12,1
# 03.29.2020,West Feliciana,LA,4,0
# 03.29.2020,Winn,LA,1,0
